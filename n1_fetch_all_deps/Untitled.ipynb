# %%
# %load_ext autoreload

# Auto reloading causes the kernel to reload the libraries we have
# %autoreload 2

import numpy as np
import pandas as pd
import datetime

from funcs import *

data_folder = 'data/'

df_dep = pd.read_csv(data_folder + 'pypi_dependencies.csv', error_bad_lines=False, warn_bad_lines=False)
df_proj = pd.read_csv(data_folder + 'pypi_projects.csv', error_bad_lines=False, warn_bad_lines=False,low_memory=False)
df_ver = pd.read_csv(data_folder + 'pypi_versions.csv', error_bad_lines=False, warn_bad_lines=False,low_memory=False)

for df in [df_proj, df_ver, df_dep]:
    time_fields = []
    for col in df.columns:
        if 'timestamp' in col:
            time_fields.append(col)
    for time_field in time_fields:
        try:
            df[time_field] = df[time_field].apply(lambda x: datetime.datetime.strptime(x, '%Y-%m-%d %H:%M:%S'))
        except:
            pass
        
del df

print(df_dep.shape)
print(df_proj.shape)
print(df_ver.shape)


package_name = 'django'
release_version = '2.1.7'
print(robust_get_dependencies(package_name, release_version))


ensure_dir('packages')
ensure_dir('tmp')

reqs = robust_extract('msrflux', '1.3', client)
# reqs = robust_extract('httpretty', '0.5', client)
# Out:
# (489009, 12)
# (172411, 21)
# (1242096, 8)
# (['pytz', 'argon2-cffi', 'bcrypt'], ['*', '>=16.1.0', '*'])

# %%
new_deps = {}
for col in df_dep.columns:
    new_deps[col] = []
del new_deps['id']

from funcs import *

# total_vers = df_ver.shape[0]
total_vers = 1000
inputs = range(total_vers)

from multiprocessing import Pool, cpu_count
with Pool(cpu_count() + 15) as p:
    all_res = (p.map(processInput2, zip([df_ver.iloc[i,:] for i in inputs],list(inputs))))


# res = map(processInput, [df_ver.iloc[i,:] for i in inputs])
# print(list(res))

# from joblib import Parallel, delayed
# import multiprocessing
# num_cores = multiprocessing.cpu_count()
# results = Parallel(n_jobs=num_cores)(delayed(processInput)(df_ver.iloc[i,:]) for i in inputs)
# print(results)

for res in all_res:
    if res is None:
        continue
    if type(res) != dict:
        continue
    for k in res.keys():
        new_deps[k] += res[k]

new_df = pd.DataFrame(data=new_deps)
new_df
# Out:
#      platform project_name  project_id version_number  version_id  \
# 0        Pypi        1pass       31613          0.1.3       22220
# 1        Pypi        1pass       31613          0.1.3       22220
# 2        Pypi        1pass       31613          0.1.4       22221
# 3        Pypi        1pass       31613          0.1.4       22221
# 4        Pypi        1pass       31613          0.1.4       22221
# 5        Pypi        1pass       31613          0.1.5       22223
# 6        Pypi        1pass       31613          0.1.5       22223
# 7        Pypi        1pass       31613          0.1.6       22226
# 8        Pypi        1pass       31613          0.1.6       22226
# 9        Pypi        1pass       31613          0.1.8       22214
# 10       Pypi        1pass       31613          0.1.8       22214
# 11       Pypi        1pass       31613          0.2.0       22216
# 12       Pypi        1pass       31613          0.2.0       22216
# 13       Pypi        1pass       31613          0.2.0       22216
# 14       Pypi        1pass       31613          0.2.1       22215
# 15       Pypi        1pass       31613          0.2.1       22215
# 16       Pypi      17MonIP       31614          0.2.2       22228
# 17       Pypi      17MonIP       31614          0.2.2       22228
# 18       Pypi      17MonIP       31614          0.2.2       22228
# 19       Pypi      17MonIP       31614          0.2.2       22228
# 20       Pypi         2gis       31619          0.8.9       22244
# 21       Pypi         2gis       31619          0.8.9       22244
# 22       Pypi         2gis       31619          0.8.9       22244
# 23       Pypi         2gis       31619          0.8.9       22244
# 24       Pypi         2gis       31619          0.9.0       22237
# 25       Pypi         2gis       31619          0.9.0       22237
# 26       Pypi         2gis       31619          1.3.1     6204426
# 27       Pypi         2gis       31619          1.3.1     6204426
# 28       Pypi         2mp4       31620          0.0.1       22259
# 29       Pypi         2mp4       31620          0.0.1       22259
# ...       ...          ...         ...            ...         ...
# 1429     Pypi     adminish       31781          0.1.3       22913
# 1430     Pypi     adminish       31781          0.1.3       22913
# 1431     Pypi        adnpy       31784          0.1.0       22930
# 1432     Pypi        adnpy       31784          0.1.0       22930
# 1433     Pypi        adnpy       31784          0.2.0       22928
# 1434     Pypi        adnpy       31784          0.2.0       22928
# 1435     Pypi        adnpy       31784          0.2.1       22927
# 1436     Pypi        adnpy       31784          0.2.1       22927
# 1437     Pypi        adnpy       31784          0.3.0       22914
# 1438     Pypi        adnpy       31784          0.3.0       22914
# 1439     Pypi        adnpy       31784          0.3.1       22917
# 1440     Pypi        adnpy       31784          0.3.1       22917
# 1441     Pypi        adnpy       31784          0.3.2       22911
# 1442     Pypi        adnpy       31784          0.3.2       22911
# 1443     Pypi        adnpy       31784          0.3.4       22924
# 1444     Pypi        adnpy       31784          0.3.4       22924
# 1445     Pypi        adnpy       31784          0.3.5       22926
# 1446     Pypi        adnpy       31784          0.3.5       22926
# 1447     Pypi        adnpy       31784          0.3.6       22920
# 1448     Pypi        adnpy       31784          0.3.7       22921
# 1449     Pypi        adnpy       31784          0.3.7       22921
# 1450     Pypi        adnpy       31784          0.3.8       22909
# 1451     Pypi          ado       31786          0.0.2       22922
# 1452     Pypi          ado       31786          0.0.2       22922
# 1453     Pypi          ado       31786          0.0.2       22922
# 1454     Pypi   AdobeColor       31787            0.1       22925
# 1455     Pypi       adrest       31792          0.3.1       22972
# 1456     Pypi       adrest       31792          0.3.1       22972
# 1457     Pypi       adrest       31792          0.4.1       23079
# 1458     Pypi       adrest       31792          0.4.3       23156
#
#       dependency_name dependency_platform dependency_kind  \
# 0            pycrypto                Pypi         runtime
# 1       simple-pbkdf2                Pypi         runtime
# 2         progressbar                Pypi         runtime
# 3         pymediainfo                Pypi         runtime
# 4                  sh                Pypi         runtime
# 5            pycrypto                Pypi         runtime
# 6       simple-pbkdf2                Pypi         runtime
# 7            pycrypto                Pypi         runtime
# 8       simple-pbkdf2                Pypi         runtime
# 9            pycrypto                Pypi         runtime
# 10      simple-pbkdf2                Pypi         runtime
# 11         fuzzywuzzy                Pypi         runtime
# 12           pycrypto                Pypi         runtime
# 13      simple-pbkdf2                Pypi         runtime
# 14         fuzzywuzzy                Pypi         runtime
# 15           m2crypto                Pypi         runtime
# 16               lxml                Pypi         runtime
# 17       progressbar2                Pypi         runtime
# 18        pymediainfo                Pypi         runtime
# 19                 sh                Pypi         runtime
# 20             jinja2                Pypi         runtime
# 21            mistune                Pypi         runtime
# 22         parguments                Pypi         runtime
# 23           pygments                Pypi         runtime
# 24           requests                Pypi         runtime
# 25                six                Pypi         runtime
# 26           requests                Pypi         runtime
# 27                six                Pypi         runtime
# 28        progressbar                Pypi         runtime
# 29             psutil                Pypi         runtime
# ...               ...                 ...             ...
# 1429     wsgiapptools                Pypi         runtime
# 1430            xappy                Pypi         runtime
# 1431  python-dateutil                Pypi         runtime
# 1432         requests                Pypi         runtime
# 1433  python-dateutil                Pypi         runtime
# 1434         requests                Pypi         runtime
# 1435  python-dateutil                Pypi         runtime
# 1436         requests                Pypi         runtime
# 1437  python-dateutil                Pypi         runtime
# 1438         requests                Pypi         runtime
# 1439  python-dateutil                Pypi         runtime
# 1440         requests                Pypi         runtime
# 1441  python-dateutil                Pypi         runtime
# 1442         requests                Pypi         runtime
# 1443  python-dateutil                Pypi         runtime
# 1444         requests                Pypi         runtime
# 1445  python-dateutil                Pypi         runtime
# 1446         requests                Pypi         runtime
# 1447             mpyq                Pypi         runtime
# 1448  python-dateutil                Pypi         runtime
# 1449         requests                Pypi         runtime
# 1450             cent                Pypi         runtime
# 1451             dexy                Pypi         runtime
# 1452         markdown                Pypi         runtime
# 1453   python-modargs                Pypi         runtime
# 1454           colour                Pypi         runtime
# 1455  python-dateutil                Pypi         runtime
# 1456         requests                Pypi         runtime
# 1457             mpyq                Pypi         runtime
# 1458             cent                Pypi         runtime
#
#       optional_dependency dependency_requirements  dependency_project_id
# 0                   False                       *                    NaN
# 1                   False                       *                    NaN
# 2                   False                       *                    NaN
# 3                   False                       *                    NaN
# 4                   False                       *                    NaN
# 5                   False                       *                    NaN
# 6                   False                       *                    NaN
# 7                   False                       *                    NaN
# 8                   False                       *                    NaN
# 9                   False                       *                    NaN
# 10                  False                       *                    NaN
# 11                  False                       *                    NaN
# 12                  False                       *                    NaN
# 13                  False                       *                    NaN
# 14                  False                       *                    NaN
# 15                  False                       *                    NaN
# 16                  False                       *                    NaN
# 17                  False                       *                    NaN
# 18                  False                       *                    NaN
# 19                  False                       *                    NaN
# 20                  False                       *                    NaN
# 21                  False                       *                    NaN
# 22                  False                       *                    NaN
# 23                  False                       *                    NaN
# 24                  False                       *                    NaN
# 25                  False                       *                    NaN
# 26                  False                       *                    NaN
# 27                  False                       *                    NaN
# 28                  False                       *                    NaN
# 29                  False                       *                    NaN
# ...                   ...                     ...                    ...
# 1429                False                       *                    NaN
# 1430                False                       *                    NaN
# 1431                False                   ==1.5                    NaN
# 1432                False                 ==2.0.1                    NaN
# 1433                False                   ==1.5                    NaN
# 1434                False                 ==2.0.1                    NaN
# 1435                False                   ==1.5                    NaN
# 1436                False                 ==2.0.1                    NaN
# 1437                False                   ==1.5                    NaN
# 1438                False                 ==2.0.1                    NaN
# 1439                False                   >=1.5                    NaN
# 1440                False                 >=2.0.1                    NaN
# 1441                False                   >=1.5                    NaN
# 1442                False                 >=2.0.1                    NaN
# 1443                False                   >=1.5                    NaN
# 1444                False                 >=2.0.1                    NaN
# 1445                False                   >=1.5                    NaN
# 1446                False                 >=2.0.1                    NaN
# 1447                False                       *                    NaN
# 1448                False                   >=1.5                    NaN
# 1449                False                 >=2.0.1                    NaN
# 1450                False                 >=0.3.0                    NaN
# 1451                False                 >=0.9.9                    NaN
# 1452                False                       *                    NaN
# 1453                False                   >=1.7                    NaN
# 1454                False                 >=0.0.4                    NaN
# 1455                False                   >=1.5                    NaN
# 1456                False                 >=2.0.1                    NaN
# 1457                False                       *                    NaN
# 1458                False                 >=0.3.0                    NaN
#
# [1459 rows x 11 columns]

# %%
new_df = pd.DataFrame(data=new_deps)
print(new_df.head())

new_df.to_csv('output/new_reqs.csv')

new_deps2 = {
    'package_name': new_deps['project_name'],
    'requirement': new_deps['dependency_name'],
}
new_df2 = pd.DataFrame(data=new_deps2)
new_df2.to_csv('output/requirements.csv')
